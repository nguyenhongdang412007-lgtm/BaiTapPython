# %%
#bài 1
n=int(input())
print(2*n)
# Out:
# 12

# %%
#bài 2
a,b=map(float,input('nhập rộng a dài b').split())
s=a*b-3.14*(a/2)**2
print('diện tích trồng cây là:','%.2f'%s)
# Out:
# diện tích trồng cây là: 7.74

# %%
#câu 3
n=input()
if n.isupper():
    print(n.lower())
else:
    print(n.upper())
# Out:
# o

# %%
#câu 4
c=input()
if c.isalpha():
    print(f"{c} là alphabet")
# Out:
# {c} là alphabet

# %%
#câu 5
chu=input('nhập chữ hoa:')
if chu=='A':print('a')
else:
     print('chữ thường liền trước:',(chr(ord(chu)+31)))
# Out:
# chữ thường liền trước: g

# %%
#câu 6
a,b,c=map(float,input().split())
if a+b>c and a+c>b and c+b>a:
    p=(a+b+c)/2
    s=p*(p-a)*(p-b)*(p-c)
    print('%.1f'%(s**0.5))
else:print('không phải 3 cạnh của tam giác')
# Out:
# 6.0

# %%
#câu 7
i=input('nhập chuỗi:')
while len(i)<20:
    i=input("nhập lại:")
print(i[4], i[6])
# Out:
# h b

# %%
#câu 8
ten=input('họ và tên:')
tt=int(input('chi so thang truoc:'))
tn=int(input('chi so thang nay:'))
dung=tn-tt
if dung>=0 and dung<=50:print(dung*1984)
elif dung>=51 and dung <=100:print(1984*50+(dung-50)*2050)
elif dung>=101 and dung<=200:print(50*1984+50*2050+(dung-100)*2380)
elif dung>=201 and dung<=300:print(50*1984+50*2050+100*2380+(dung-200)*2998)
elif dung>=301 and dung<=400:print(50*1984+50*2050+100*2380+100*2998+(dung-300)*3350)
elif dung>=401 and dung<=500:print(50*1984+50*2050+100*2380+100*2998+100*3350+(dung-400)*3460)
# Out:
# 45632
