# %%
#câu 1
n=int(input('nhập số:'))
dao=0
while n!=0:
    dao=dao*10+n%10
    n//=10
print(dao)
# Out:
# 987

# %%
#câu 2

# %%
#câu 3
n=int(input())
print(n>>1)
# Out:
# 2

# %%
#câu 4
m,n=map(int,input().split())
print(m//n)
# Out:
# 1

# %%
#câu 5
m,n=map(int,input().split())
import math
print(math.ceil(m/n))
# Out:
# 2

# %%
#câu 6
x=int(input())
if x%2==0:print('Even')
else:print('Odd')
# Out:
# Odd

# %%
#câu 7
a,b=map(int,input().split())
if a<0 and b<0:print('yes')
else:print('no')
# Out:
# yes

# %%
#câu 8
a,b=map(str,input().split())
if len(a)>len(b):print('true')
else:print('false')
# Out:
# true

# %%
#câu 9
a,b,c=map(int,input().split())
if a+b>c and a+c>b and b+c>a:print('yes')
else:print('no')
# Out:
# no

# %%
#câu 10
a,b,c,d=map(int,input().split())
print(max(a,b,c,d))
# Out:
# 9

# %%
#câu 11
a,b,c=map(int,input().split())
if a+b>c and a+c>b and b+c>a:
    if a==b==c:print('tam giác đều')
    elif a==b or a==c or b==c:print('tam giác cân')
    else:print('tam giác thường')
else :print('không phải tam giác')
# Out:
# không phải tam giác

# %%
#câu 12
n=int(input())
if (n%4==0 and n%100!=0 )or n%400==0:print('yes')
else:print('no')
# Out:
# no

# %%
#câu 13
n=int(input())
if n>=0 and n<=50:print(1500*n)
elif n>=51 and n<=100:print(1500*50+(n-50)*2000)
elif n<=0:print('invalid')
else:print(1500*50+2000*50+3000*(n-100))
# Out:
# 235000

# %%
#câu 14
a,b=map(int,input().split())
if a==0 and b==0:print('vô số nghiệm')
if a==0 and b!=0:print('vô nghiệm')
else:print('nghiệm là:','%.2f'%(-b/a))
# Out:
# nghiệm là: -1.12

# %%
#câu 15
n=float(input('nhập điểm:'))
if n>=8:print('giỏi')
elif n>=6.5:print('khá')
elif n>=5.0:print('trung bình')
else:print('yếu')
# Out:
# giỏi

# %%
#câu 16
n=float(input())
if n==int(n):
    print(int(n),int(n),int(n))
elif n-int(n)>=0.5:
    print(int(n+1),int(n),int(n+1))
elif n-int(n)<0.5:
    print(int(n+1),int(n),int(n))
# Out:
# 10 9 9
